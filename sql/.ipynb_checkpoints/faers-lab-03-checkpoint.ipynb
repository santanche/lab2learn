-- %%
%defaultDatasource jdbc:h2:mem:db

-- %%
DROP TABLE IF EXISTS Pessoa;
DROP TABLE IF EXISTS Medicamento;
DROP TABLE IF EXISTS Patologia;
DROP TABLE IF EXISTS Indicacao;
DROP TABLE IF EXISTS EfeitoColateral;

CREATE TABLE Pessoa (
  IdPessoa INT NOT NULL,
  Idade INTEGER,
  Genero VARCHAR(1),
  PRIMARY KEY(IdPessoa)
) AS SELECT
    IdPessoa,
    Idade,
    Genero
FROM CSVREAD('../data/faers-2017/demo.csv');

CREATE TABLE Medicamento (
  CodigoMedicamento INT NOT NULL,
  NomeMedicamento VARCHAR(200) NOT NULL,
  PRIMARY KEY(CodigoMedicamento)
) AS SELECT
    CodigoMedicamento,
    NomeMedicamento
FROM CSVREAD('../data/faers-2017/drug.csv');

CREATE TABLE Patologia (
  IdPatologia INT NOT NULL,
  NomePatologia VARCHAR(200) NOT NULL,
  PRIMARY KEY(IdPatologia)
) AS SELECT
    IdPatologia,
    NomePatologia
FROM CSVREAD('../data/faers-2017/affection.csv');

CREATE TABLE Indicacao (
  IdPessoa INT NOT NULL,
  IdPatologia INT NOT NULL,
  CodigoMedicamento INT NOT NULL,
  FOREIGN KEY(IdPessoa)
    REFERENCES pessoa(IdPessoa)
      ON DELETE NO ACTION
      ON UPDATE NO ACTION,
  FOREIGN KEY(CodigoMedicamento)
    REFERENCES medicamento(CodigoMedicamento)
      ON DELETE NO ACTION
      ON UPDATE NO ACTION,
  FOREIGN KEY(IdPatologia)
    REFERENCES patologia(IdPatologia)
      ON DELETE NO ACTION
      ON UPDATE NO ACTION,
) AS SELECT
    IdPessoa,
    IdPatologia,
    CodigoMedicamento
FROM CSVREAD('../data/faers-2017/indication.csv');

CREATE TABLE EfeitoColateral (
  IdPessoa INT NOT NULL,
  IdPatologia INT NOT NULL,
  FOREIGN KEY(IdPessoa)
    REFERENCES pessoa(IdPessoa)
      ON DELETE NO ACTION
      ON UPDATE NO ACTION,
  FOREIGN KEY(IdPatologia)
    REFERENCES patologia(IdPatologia)
      ON DELETE NO ACTION
      ON UPDATE NO ACTION
) AS SELECT
    IdPessoa,
    IdPatologia
FROM CSVREAD('../data/faers-2017/sideeffect.csv');
