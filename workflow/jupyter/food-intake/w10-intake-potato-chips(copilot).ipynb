# %% [markdown]
# # Plotting Correlation between Potato Chips Intake and Age
# *Assisted by Copilot*

# %%
# Read a CSV file in the relative path ../../../data/food-intake/grouped/intake-person-demo(potato-chips).csv
# and print the first five rows of the file

import pandas as pd

# Read the CSV file
df = pd.read_csv('../../../data/food-intake/grouped/intake-person-demo(potato-chips).csv')

# Print the first five rows of the file
print(df.head())
# Out:
#    fcid_code  age  gender  ethnicity  height  bodyweight  intake_bw
# 0  103296000    0       2          4    70.4         9.4   0.315893
# 1  103296000    0       1          1    68.9        10.1   0.460173
# 2  103296000    0       2          5    78.4        11.1   0.258317
# 3  103296000    0       1          4    69.8         8.4   0.414977
# 4  103296000    0       1          1    79.3        13.0   0.496554

# %%
# Draw a scatter plot of this file with age vs. intake_bw
# changing the bullet color of intake_bw according to its value

import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df['age'], df['intake_bw'], c=df['intake_bw'], cmap='viridis')

# Add labels to the plot
plt.xlabel('Age')
plt.ylabel('Intake BW')
plt.title('Age vs. Intake BW')

# Show the plot
plt.show()
