# %% [markdown]
# # Plotting Popularity vs. Recipes
# *Assisted by Claude.ai*

# %% [markdown]
# *First interaction:*
#
# How can a write a Python + Pandas program over Jupyter to do the following:
# 1. read a CVS file named commodity-profile.csv
# 2. Draw a scatter plot of the columns: popularity vs recipes
#
# *Second interaction:*
#
# How do I change the color of the bullets according to the value of popularity?
#
# *Result:*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file
df = pd.read_csv('../../../data/food-intake/profile/commodity-profile.csv')

# Show the file content
df.head()
# Out:
#     FCID_CODE                          FCID_DESC  CGN CG_SUBGROUP  POPULARITY  \
# 0  4000095001  Chicken, meat byproducts-babyfood   40          40         169
# 1  1202012000                            Apricot   12         12B        1131
# 2  1202012001                   Apricot-babyfood   12         12B          30
# 3  2402245000                             Papaya   24         24B         257
# 4  1800002000                      Alfalfa, seed   18          18          44
#
#      INTAKE_SUM  INTAKE_AVG  INTAKE_BW_AVG  RECIPES
# 0    199.587311    1.002951       0.110415       16
# 1  12664.223672    9.932724       0.226555       25
# 2    411.790886   12.111497       1.336298        7
# 3  16911.764954   63.578064       1.715825        5
# 4     53.386830    1.112226       0.014007        2

# %%
# Create a scatter plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(df['POPULARITY'], df['RECIPES'], c=df['POPULARITY'], cmap='viridis', s=50)


# Add labels and title
plt.xlabel('Popularity')
plt.ylabel('Recipes')
plt.title('Popularity vs Recipes Scatter Plot')

# Add a color bar
cbar = plt.colorbar(scatter)
cbar.set_label('Popularity', fontsize=12)

# Improve the layout
plt.tight_layout()

# Show the plot
plt.show()
