# %% [markdown]
# # World Health Organization Data
#
# ## Global Health Observatory
#
# * [Data query API](https://apps.who.int/gho/data/node.resources.api)
# * [GHO OData API ](https://www.who.int/data/gho/info/gho-odata-api)
#
# Exemplos de API: [https://www.who.int/data/gho/info/athena-api-examples](https://www.who.int/data/gho/info/athena-api-examples).
#
# Para se determinar o tipo de informação para acesso veja a [lista de dimensões e códigos](https://apps.who.int/gho/athena/api/GHO). Utilize o código disponível no campo `<Code label="">`. Por exemplo, no campo `<Code Label="WHOSIS_000001">` é possível encontrar o código `WHOSIS_000001` que indica `Life expectancy at birth (years)`.
#
# Depois de estabelecida a informação, podem ser configurados parâmetros, com o sufixo `?` depois da URL. Os parâmetros são separados por `&`.
#
# Os códigos dos países são encontrados em: [https://apps.who.int/gho/athena/api/COUNTRY](https://apps.who.int/gho/athena/api/COUNTRY).

# %%
import requests
url = "https://apps.who.int/gho/athena/api/COUNTRY"
data = requests.get(url)
print(data.content.decode("utf-8"))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <GHO Created="2021-08-20T15:46:46Z"
#      xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#      xsi:schemaLocation="ghodata.xsd">
#     <QueryParameter Name="baseurl" Value="https://apps.who.int/gho/athena/api/"/>
#     <QueryParameter Name="asof" Value="2021-08-19 17:51:02.0"/>
#     <QueryParameter Name="metadata" Value="active"/>
#     <QueryParameter Name="target" Value="COUNTRY"/>
#     <Copyright><Display>(c) World Health Organization</Display></Copyright>
#     <Disclaimer><Display>The information in this database is provided as a service to our users.
# Any use of information in the web site should be accompanied by an
# acknowledgment of WHO as the source. The responsibility for the
# interpretation and use of the material lies with the user. In no event
# shall the World Health Organization be liable for any damages arising
# from the use of the information linked to this section.</Display></Disclaimer>
# <Metadata>
# <Attribute Label="DS" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>DS</Display>
# </Attribute>
# <Attribute Label="FIPS" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>FIPS</Display>
# </Attribute>
# <Attribute Label="IOC" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>IOC</Display>
# </Attribute>
# <Attribute Label="ISO2" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>ISO2</Display>
# </Attribute>
# <Attribute Label="ISO" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>ISO</Display>
# </Attribute>
# <Attribute Label="ITU" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>ITU</Display>
# </Attribute>
# <Attribute Label="MARC" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>MARC</Display>
# </Attribute>
# <Attribute Label="WHO" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>WHO</Display>
# </Attribute>
# <Attribute Label="WMO" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>WMO</Display>
# </Attribute>
# <Attribute Label="GEOMETRY" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>GEOMETRY</Display>
# </Attribute>
# <Attribute Label="MORT" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>MORT</Display>
# </Attribute>
# <Attribute Label="LAND_AREA_KMSQ_2012" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>LAND_AREA_KMSQ_2012</Display>
# </Attribute>
# <Attribute Label="LANGUAGES_EN_2012" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>LANGUAGES_EN_2012</Display>
# </Attribute>
# <Attribute Label="WHO_REGION" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>WHO_REGION</Display>
# </Attribute>
# <Attribute Label="WHO_REGION_CODE" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>WHO_REGION_CODE</Display>
# </Attribute>
# <Attribute Label="WORLD_BANK_INCOME_GROUP" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>World Bank income group</Display>
# </Attribute>
# <Attribute Label="WORLD_BANK_INCOME_GROUP_CODE" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>World Bank income group code</Display>
# </Attribute>
# <Attribute Label="SHORTNAMEES" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>SHORTNAMEES</Display>
# </Attribute>
# <Attribute Label="SHORTNAMEFR" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>SHORTNAMEFR</Display>
# </Attribute>
# <Attribute Label="WHOLEGALSTATUS" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>WHOLEGALSTATUS</Display>
# </Attribute>
# <Attribute Label="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>World Bank income group GNI reference year</Display>
# </Attribute>
# <Attribute Label="WORLD_BANK_INCOME_GROUP_RELEASE_DATE" EntityType="CORE_DIMENSION" Entity="COUNTRY">
# <Display>World Bank income group release date</Display>
# </Attribute>
# <Dimension Label="COUNTRY">
# <Display>Country</Display>
# <Code Label="AFG" DisplaySequence="10">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Eastern Mediterranean</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Low income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AF</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AF</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>af</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AF</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AFG</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>3010</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>652,230</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Dari, Pashto, Turkic languages, 30 minor languages</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Afganistan</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Afghanistan</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Afghanistan</Display>
# </Code>
# <Code Label="ALB" DisplaySequence="20">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AL</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AL</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ALB</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AB</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>ALB</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4005</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>ALB</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>aa</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ALB</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AL</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>ALB</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>27,400</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Albanian, Greek, Vlach, Romani, Slavic dialects</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Albania</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Albanie</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Albania</Display>
# </Code>
# <Code Label="DZA" DisplaySequence="30">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>2,381,740</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Arabic, French, Berber dialects</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Argelia</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Algérie</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Africa</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AFR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>DZ</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AG</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ALG</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>DZ</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>DZA</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>ALG</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>ae</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ALG</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AL</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>DZA</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>1010</Display></Value>
# </Attr>
# <Display>Algeria</Display>
# </Code>
# <Code Label="AND" DisplaySequence="40">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>470</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Catalan, French, Castilian, Portuguese </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AN</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AD</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>an</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AND</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4008</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Andorra</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Andorre</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Andorra</Display>
# </Code>
# <Code Label="AGO" DisplaySequence="50">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>1,246,700</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Portuguese, Bantu,  other African languages </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Africa</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AFR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AO</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ANG</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AN</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AGO</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>1020</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AGL</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>ao</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ANG</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AO</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AGO</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Angola</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Angola</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Angola</Display>
# </Code>
# <Code Label="ATG" DisplaySequence="60">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>440</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>English, local dialects </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AC</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ANT</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AT</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>ATG</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2010</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>ATG</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>aq</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ANI</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AG</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>ATG</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Antigua y Barbuda</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Antigua-et-Barbuda</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Antigua and Barbuda</Display>
# </Code>
# <Code Label="ARG" DisplaySequence="70">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>2,736,690</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Spanish, others</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>RA</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AR</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ARG</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AG</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>ARG</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2020</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>ARG</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>ag</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ARG</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AR</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>ARG</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Argentina</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Argentine</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Argentina</Display>
# </Code>
# <Code Label="ARM" DisplaySequence="80">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>28,480</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Armenian</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AM</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AM</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>ARM</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AY</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>ARM</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4007</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>ARM</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>ai</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>ARM</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AM</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>ARM</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Armenia</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Arménie</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Armenia</Display>
# </Code>
# <Code Label="AUS" DisplaySequence="90">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>7,682,300</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>English </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Western Pacific</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>WPR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AS</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AU</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>at</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AU</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AUS</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>5020</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Australia</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Australie</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Australia</Display>
# </Code>
# <Code Label="AUT" DisplaySequence="100">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>83,871</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>German</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>A</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AU</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>AUT</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AT</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AUT</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AUT</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Austria</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Autriche</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>au</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>AUT</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>OS</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AUT</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4010</Display></Value>
# </Attr>
# <Display>Austria</Display>
# </Code>
# <Code Label="AZE" DisplaySequence="110">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>82,450</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Azerbaijani, others</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Azerbaijan</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>AZ</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>AJ</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>AZE</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>AZ</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>AZE</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>AZE</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>aj</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>AZE</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>AJ</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>AZE</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4012</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Azerbaïdjan</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Azerbaijan</Display>
# </Code>
# <Code Label="BHS" DisplaySequence="120">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>10,010</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>English, Creole </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BS</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BF</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BAH</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BS</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BHS</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BAH</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bf</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BAH</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BA</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BHS</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2030</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bahamas</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bahamas</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Bahamas</Display>
# </Code>
# <Code Label="BHR" DisplaySequence="130">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>760</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Arabic, English, Farsi, Urdu</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Eastern Mediterranean</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BRN</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BA</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BRN</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BN</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BHR</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>3020</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BHR</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>ba</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BAA</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BH</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BHR</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bahrein</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bahreïn</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Bahrain</Display>
# </Code>
# <Code Label="BGD" DisplaySequence="140">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>130,170</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Bangla, English</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>South-East Asia</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>SEAR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BD</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BG</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BAN</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BD</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BGD</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BGD</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bg</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BAN</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BW</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BGD</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>3025</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bangladesh</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bangladesh</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Bangladesh</Display>
# </Code>
# <Code Label="BRB" DisplaySequence="150">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>430</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>English</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BDS</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BB</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BAR</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BB</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BRB</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BRB</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bb</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BAR</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BR</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BRB</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2040</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Barbados</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Barbade</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Barbados</Display>
# </Code>
# <Code Label="BLR" DisplaySequence="160">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>202,900</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Belarusian, Russian</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BY</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BO</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BLR</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BY</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BLR</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BLR</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bw</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BLR</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BY</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BLR</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4018</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Belarus</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bélarus</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Belarus</Display>
# </Code>
# <Code Label="BEL" DisplaySequence="170">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>30,280</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Dutch, French, German</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>B</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BE</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BEL</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BE</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BEL</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BEL</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>be</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BEL</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BX</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BEL</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4020</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Belgica</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Belgique</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Belgium</Display>
# </Code>
# <Code Label="BLZ" DisplaySequence="180">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>22,810</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Spanish, Creole, Mayan dialects, English</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BZ</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BH</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BIZ</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BZ</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BLZ</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BLZ</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bh</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BLZ</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BH</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BLZ</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2045</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Belice</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Belize</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Display>Belize</Display>
# </Code>
# <Code Label="BEN" DisplaySequence="190">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>112,760</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>French, Fon, Yoruba, tribal languages</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Africa</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Low income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AFR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LI</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>DY</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BN</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BEN</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BJ</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BEN</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BEN</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>dm</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BEN</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BJ</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Benin</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bénin</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BEN</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>1025</Display></Value>
# </Attr>
# <Display>Benin</Display>
# </Code>
# <Code Label="BTN" DisplaySequence="200">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>38,394</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Sharchhopka, Dzongkha, Lhotshamkha, others</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>South-East Asia</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>SEAR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bhutan</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bhoutan</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BT</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BHU</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BTN</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>3027</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BTN</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bt</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BHU</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BT</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BTN</Display></Value>
# </Attr>
# <Display>Bhutan</Display>
# </Code>
# <Code Label="BOL" DisplaySequence="210">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>1,083,300</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Spanish, Quechua, Aymara</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bolivia (Estado Plurinacional de)  </Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bolivie (État plurinational de)</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BL</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BO</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bo</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BO</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BOL</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2060</Display></Value>
# </Attr>
# <Display>Bolivia (Plurinational State of)</Display>
# </Code>
# <Code Label="BIH" DisplaySequence="220">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>51,000</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Bosnian, Croatian, Serbian </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Europe</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EUR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Bosnia y Herzegovina</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Bosnie-Herzégovine</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BK</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BG</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4025</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bn</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BA</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BIH</Display></Value>
# </Attr>
# <Display>Bosnia and Herzegovina</Display>
# </Code>
# <Code Label="BWA" DisplaySequence="230">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>566,730</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Setswana, Kalanga, English </Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Africa</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AFR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Botswana</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Botswana</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BW</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BC</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BOT</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BC</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BWA</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>1030</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>BOT</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bs</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BOT</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BW</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BWA</Display></Value>
# </Attr>
# <Display>Botswana</Display>
# </Code>
# <Code Label="BRA" DisplaySequence="240">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>8,459,420</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Portuguese</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Americas</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>Brasil</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Brésil</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>BR</Display></Value>
# </Attr>
# <Attr Category="FIPS">
# <Value><Display>BR</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>BRA</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>BR</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>BRA</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>B</Display></Value>
# </Attr>
# <Attr Category="MARC">
# <Value><Display>bl</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>BRA</Display></Value>
# </Attr>
# <Attr Category="WMO">
# <Value><Display>BZ</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BRA</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>2070</Display></Value>
# </Attr>
# <Display>Brazil</Display>
# </Code>
# <Code Label="BRN" DisplaySequence="250">
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="LAND_AREA_KMSQ_2012">
# <Value><Display>5270</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>English, Malay, Chinese</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Western Pacific</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# ...
# </Code>
# <Code Label="X11" DisplaySequence="0">
# <Attr Category="GEOMETRY">
# <Value><Display>X11</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4320</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>X11</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>United Kingdom, Northern Ireland</Display>
# </Code>
# <Code Label="X12" DisplaySequence="0">
# <Attr Category="ISO">
# <Value><Display>X12</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>X12</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4330</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>United Kingdom, Scotland</Display>
# </Code>
# <Code Label="X13" DisplaySequence="0">
# <Attr Category="ISO">
# <Value><Display>X13</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>X13</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4340</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Yugoslavia, Former</Display>
# </Code>
# <Code Label="SCG" DisplaySequence="1530">
# <Attr Category="GEOMETRY">
# <Value><Display>SCG</Display></Value>
# </Attr>
# <Attr Category="MORT">
# <Value><Display>4350</Display></Value>
# </Attr>
# <Attr Category="ISO2">
# <Value><Display>CS</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>SCG</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Serbia and Montenegro, Former</Display>
# </Code>
# <Code Label="PSE" DisplaySequence="1275">
# <Attr Category="ISO">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower middle income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="DS">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="IOC">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="ITU">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="LANGUAGES_EN_2012">
# <Value><Display>Arabic</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEES">
# <Value><Display>occupied Palestinian territory</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>occupied Palestinian territory</Display></Value>
# </Attr>
# <Attr Category="WHO">
# <Value><Display>PSE</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Eastern Mediterranean</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EMR</Display></Value>
# </Attr>
# <Display>occupied Palestinian territory, including east Jerusalem</Display>
# </Code>
# <Code Label="NA" DisplaySequence="0">
# <Attr Category="GEOMETRY">
# <Value><Display>NA</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>NA</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>NA</Display>
# </Code>
# <Code Label="GUM" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>GUM</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>GUM</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Guam</Display>
# </Code>
# <Code Label="MYT" DisplaySequence="0">
# <Attr Category="ISO">
# <Value><Display>MYT</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>MYT</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Mayotte</Display>
# </Code>
# <Code Label="PYF" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>PYF</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>PYF</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>French Polynesia</Display>
# </Code>
# <Code Label="FRO" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>FRO</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>FRO</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Faroe Islands</Display>
# </Code>
# <Code Label="GRL" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>GRL</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>GRL</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Greenland</Display>
# </Code>
# <Code Label="SHN" DisplaySequence="0">
# <Attr Category="GEOMETRY">
# <Value><Display>SHN</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>SHN</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Saint Helena</Display>
# </Code>
# <Code Label="NCL" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>NCL</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>NCL</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>New Caledonia</Display>
# </Code>
# <Code Label="ASM" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Upper middle income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_UMI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>ASM</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>ASM</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>American Samoa</Display>
# </Code>
# <Code Label="TKL" DisplaySequence="1760">
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>A</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>TKL</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>TKL</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Tokelau</Display>
# </Code>
# <Code Label="MNP" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>MNP</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>MNP</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Northern Mariana Islands</Display>
# </Code>
# <Code Label="GIB" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>GIB</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>GIB</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Display>Gibraltar</Display>
# </Code>
# <Code Label="LIE" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>LIE</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>LIE</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Liechtenstein</Display>
# </Code>
# <Code Label="PCN" DisplaySequence="0">
# <Attr Category="GEOMETRY">
# <Value><Display>PCN</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>PCN</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Pitcairn Island</Display>
# </Code>
# <Code Label="WLF" DisplaySequence="0">
# <Attr Category="ISO">
# <Value><Display>WLF</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>WLF</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Wallis and Futuna Islands</Display>
# </Code>
# <Code Label="NFK" DisplaySequence="0">
# <Attr Category="GEOMETRY">
# <Value><Display>NFK</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>NFK</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Norfolk Island</Display>
# </Code>
# <Code Label="BES" DisplaySequence="0">
# <Attr Category="ISO">
# <Value><Display>BES</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>BES</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Bonaire, Saint Eustatius and Saba</Display>
# </Code>
# <Code Label="CUW" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>CUW</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>CUW</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Curaçao</Display>
# </Code>
# <Code Label="SXM" DisplaySequence="0">
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>High income</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_HI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>SXM</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>SXM</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Sint Maarten (Dutch part)</Display>
# </Code>
# <Code Label="SSD" DisplaySequence="1620">
# <Attr Category="SHORTNAMEES">
# <Value><Display> Sudan del Sur</Display></Value>
# </Attr>
# <Attr Category="SHORTNAMEFR">
# <Value><Display>Soudan du Sud</Display></Value>
# </Attr>
# <Attr Category="WHOLEGALSTATUS">
# <Value><Display>M</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION">
# <Value><Display>Africa</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Low income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>AFR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LI</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>SSD</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>SSD</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>South Sudan</Display>
# </Code>
# <Code Label="SDF" DisplaySequence="1655">
# <Attr Category="WHO_REGION">
# <Value><Display>Eastern Mediterranean</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP">
# <Value><Display>Lower-middle-income</Display></Value>
# </Attr>
# <Attr Category="WHO_REGION_CODE">
# <Value><Display>EMR</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_CODE">
# <Value><Display>WB_LMI</Display></Value>
# </Attr>
# <Attr Category="ISO">
# <Value><Display>SDF</Display></Value>
# </Attr>
# <Attr Category="GEOMETRY">
# <Value><Display>SDN</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR">
# <Value><Display>2017</Display></Value>
# </Attr>
# <Attr Category="WORLD_BANK_INCOME_GROUP_RELEASE_DATE">
# <Value><Display>2018</Display></Value>
# </Attr>
# <Display>Sudan (former)</Display>
# </Code>
# <Code Label="CHI" DisplaySequence="0">
# <Display>Channel islands</Display>
# </Code>
# <Code Label="IMN" DisplaySequence="0">
# <Display>Isle of Man</Display>
# </Code>
# </Dimension>
# </Metadata>
# </GHO>

# %% [markdown]
# ## Importando dados em JSON no Python
#
# ![JSON](json.png)

# %%
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {
# "copyright": "(c) World Health Organization",
# "dataset":
# [
# {
# "label": "CYCU",
# "display": "COUNTRY_YEARLY_CORE_UNITS"
# }
# ],
# "attribute":
# [
# {
# "label": "DS",
# "display": "DS"
# },
# {
# "label": "FIPS",
# "display": "FIPS"
# },
# {
# "label": "IOC",
# "display": "IOC"
# },
# {
# "label": "ISO2",
# "display": "ISO2"
# },
# {
# "label": "ISO",
# "display": "ISO"
# },
# {
# "label": "ITU",
# "display": "ITU"
# },
# {
# "label": "MARC",
# "display": "MARC"
# },
# {
# "label": "WHO",
# "display": "WHO"
# },
# {
# "label": "WMO",
# "display": "WMO"
# },
# {
# "label": "GEOMETRY",
# "display": "GEOMETRY"
# },
# {
# "label": "MORT",
# "display": "MORT"
# },
# {
# "label": "LAND_AREA_KMSQ_2012",
# "display": "LAND_AREA_KMSQ_2012"
# },
# {
# "label": "LANGUAGES_EN_2012",
# "display": "LANGUAGES_EN_2012"
# },
# {
# "label": "WHO_REGION",
# "display": "WHO_REGION"
# },
# {
# "label": "WHO_REGION_CODE",
# "display": "WHO_REGION_CODE"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP",
# "display": "World Bank income group"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_CODE",
# "display": "World Bank income group code"
# },
# {
# "label": "SHORTNAMEES",
# "display": "SHORTNAMEES"
# },
# {
# "label": "SHORTNAMEFR",
# "display": "SHORTNAMEFR"
# },
# {
# "label": "WHOLEGALSTATUS",
# "display": "WHOLEGALSTATUS"
# },
# {
# "label": "CATEGORY",
# "display": "Category"
# },
# {
# "label": "RENDERER_ID",
# "display": "Renderer ID"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR",
# "display": "World Bank income group GNI reference year"
# },
# {
# "label": "WORLD_BANK_INCOME_GROUP_RELEASE_DATE",
# "display": "World Bank income group release date"
# },
# {
# "label": "DEFINITION_XML",
# "display": "Definition (XML)"
# },
# {
# "label": "DISPLAY_FR",
# "display": "Français"
# },
# {
# "label": "DISPLAY_ES",
# "display": "Español"
# }
# ],
# "dimension":
# [
# {
# "label": "GHO",
# "display": "Indicator",
# "isMeasure": true,
# "code":
# [
# {
# "label": "WHOSIS_000001",
# "display": "Life expectancy at birth (years)",
# "display_sequence": 10,
# "url": "https://www.who.int/data/gho/indicator-metadata-registry/imr-details/65",
# "attr":
# [
# {
# "category": "DISPLAY_FR",
# "value": "Esperance de vie a la naissance (ans)"
# },
# {
# "category": "DISPLAY_ES",
# "value": "Esperanza de vida al nacer"
# },
# {
# "category": "DEFINITION_XML",
# "value": "http://apps.who.int/gho/indicatorregistryservice/publicapiservice.asmx/IndicatorGetAsXml?profileCode=WHO&applicationCode=System&languageAlpha2=en&indicatorId=65"
# },
# {
# "category": "CATEGORY",
# "value": "Sustainable development goals"
# },
# {
# "category": "RENDERER_ID",
# "value": "RENDER_2"
# }
# ]
# }
# ]
# },
# {
# "label": "PUBLISHSTATE",
# "display": "PUBLISH STATES",
# "isMeasure": false,
# "code":
# [
# {
# "label": "PUBLISHED",
# "display": "Published",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "YEAR",
# "display": "Year",
# "isMeasure": false,
# "code":
# [
# {
# "label": "2000",
# "display": "2000",
# "display_sequence": 79998000,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2010",
# "display": "2010",
# "display_sequence": 79897990,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2015",
# "display": "2015",
# "display_sequence": 79847985,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "2019",
# "display": "2019",
# "display_sequence": 79807981,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "REGION",
# "display": "WHO region",
# "isMeasure": false,
# "code":
# [
# {
# "label": "AMR",
# "display": "Americas",
# "display_sequence": 20,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# },
# {
# "label": "COUNTRY",
# "display": "Country",
# "isMeasure": false,
# "code":
# [
# {
# "label": "BRA",
# "display": "Brazil",
# "display_sequence": 240,
# "url": "",
# "attr":
# [
# {
# "category": "WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR",
# "value": "2017"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP_RELEASE_DATE",
# "value": "2018"
# },
# {
# "category": "LAND_AREA_KMSQ_2012",
# "value": "8,459,420"
# },
# {
# "category": "LANGUAGES_EN_2012",
# "value": "Portuguese"
# },
# {
# "category": "WHO_REGION",
# "value": "Americas"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP",
# "value": "Upper middle income"
# },
# {
# "category": "WHO_REGION_CODE",
# "value": "AMR"
# },
# {
# "category": "WORLD_BANK_INCOME_GROUP_CODE",
# "value": "WB_UMI"
# },
# {
# "category": "SHORTNAMEES",
# "value": "Brasil"
# },
# {
# "category": "SHORTNAMEFR",
# "value": "Brésil"
# },
# {
# "category": "WHOLEGALSTATUS",
# "value": "M"
# },
# {
# "category": "DS",
# "value": "BR"
# },
# {
# "category": "FIPS",
# "value": "BR"
# },
# {
# "category": "IOC",
# "value": "BRA"
# },
# {
# "category": "ISO2",
# "value": "BR"
# },
# {
# "category": "ISO",
# "value": "BRA"
# },
# {
# "category": "ITU",
# "value": "B"
# },
# {
# "category": "MARC",
# "value": "bl"
# },
# {
# "category": "WHO",
# "value": "BRA"
# },
# {
# "category": "WMO",
# "value": "BZ"
# },
# {
# "category": "GEOMETRY",
# "value": "BRA"
# },
# {
# "category": "MORT",
# "value": "2070"
# }
# ]
# }
# ]
# },
# {
# "label": "SEX",
# "display": "Sex",
# "isMeasure": false,
# "code":
# [
# {
# "label": "MLE",
# "display": "Male",
# "display_sequence": 2,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "FMLE",
# "display": "Female",
# "display_sequence": 3,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "BTSX",
# "display": "Both sexes",
# "display_sequence": 1,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# }
# ],
# "fact":
# [
# {
# "fact_id": 24615369,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "67.9",
# "numeric": 67.89800,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615373,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "70.6",
# "numeric": 70.57493,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615377,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "MLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "71.7",
# "numeric": 71.66687,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615381,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2019"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "MLE"
# }
# ],
# "value":
# {
# "display": "72.4",
# "numeric": 72.44810,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615385,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "75.2",
# "numeric": 75.18223,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615389,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "77.7",
# "numeric": 77.68340,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615393,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "78.6",
# "numeric": 78.64028,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615397,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "YEAR",
# "code": "2019"
# },
# {
# "category": "SEX",
# "code": "FMLE"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# }
# ],
# "value":
# {
# "display": "79.4",
# "numeric": 79.38875,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615401,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "YEAR",
# "code": "2000"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "71.5",
# "numeric": 71.46612,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615405,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "YEAR",
# "code": "2010"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "74.1",
# "numeric": 74.09258,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615409,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# },
# {
# "category": "YEAR",
# "code": "2015"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# }
# ],
# "value":
# {
# "display": "75.1",
# "numeric": 75.13264,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# },
# {
# "fact_id": 24615413,
# "dataset": "CYCU",
# "effective_date": "2020-12-04",
# "end_date": "2900-12-31",
# "published": true,
# "Dim":
# [
# {
# "category": "PUBLISHSTATE",
# "code": "PUBLISHED"
# },
# {
# "category": "REGION",
# "code": "AMR"
# },
# {
# "category": "SEX",
# "code": "BTSX"
# },
# {
# "category": "YEAR",
# "code": "2019"
# },
# {
# "category": "GHO",
# "code": "WHOSIS_000001"
# },
# {
# "category": "COUNTRY",
# "code": "BRA"
# }
# ],
# "value":
# {
# "display": "75.9",
# "numeric": 75.90331,
# "low": null,
# "high": null,
# "stderr": null,
# "stddev": null
# }
# }
# ]
# }

# %% [markdown]
# ### Mostrando o Copyright

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
data = requests.get(url)
js = data.json()
print(js["copyright"])
# Out:
# (c) World Health Organization

# %% [markdown]
# ## Importando dados em CSV no Python
#
# ![CSV](csv.png)

# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#               GHO PUBLISHSTATE  YEAR REGION COUNTRY   SEX  Display Value  \
# 0   WHOSIS_000001    PUBLISHED  2000    AMR     BRA   MLE           67.9
# 1   WHOSIS_000001    PUBLISHED  2010    AMR     BRA   MLE           70.6
# 2   WHOSIS_000001    PUBLISHED  2015    AMR     BRA   MLE           71.7
# 3   WHOSIS_000001    PUBLISHED  2019    AMR     BRA   MLE           72.4
# 4   WHOSIS_000001    PUBLISHED  2000    AMR     BRA  FMLE           75.2
# 5   WHOSIS_000001    PUBLISHED  2010    AMR     BRA  FMLE           77.7
# 6   WHOSIS_000001    PUBLISHED  2015    AMR     BRA  FMLE           78.6
# 7   WHOSIS_000001    PUBLISHED  2019    AMR     BRA  FMLE           79.4
# 8   WHOSIS_000001    PUBLISHED  2000    AMR     BRA  BTSX           71.5
# 9   WHOSIS_000001    PUBLISHED  2010    AMR     BRA  BTSX           74.1
# 10  WHOSIS_000001    PUBLISHED  2015    AMR     BRA  BTSX           75.1
# 11  WHOSIS_000001    PUBLISHED  2019    AMR     BRA  BTSX           75.9
#
#      Numeric  Low  High  Comments
# 0   67.89800  NaN   NaN       NaN
# 1   70.57493  NaN   NaN       NaN
# 2   71.66687  NaN   NaN       NaN
# 3   72.44810  NaN   NaN       NaN
# 4   75.18223  NaN   NaN       NaN
# 5   77.68340  NaN   NaN       NaN
# 6   78.64028  NaN   NaN       NaN
# 7   79.38875  NaN   NaN       NaN
# 8   71.46612  NaN   NaN       NaN
# 9   74.09258  NaN   NaN       NaN
# 10  75.13264  NaN   NaN       NaN
# 11  75.90331  NaN   NaN       NaN

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Importando dados em XML no Python
#
# ![XML](xml.png)

# %%
import io
import requests
import xml.etree.ElementTree as et
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(x)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7ff5cb490b50>
